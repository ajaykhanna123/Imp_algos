# %%
text="""1.My phone number is 212-555-5555. 
        Mr Ajay got fever and gave him paracetemol.
        Street: 2425 Crosswind Drive City: Henderson  State/province/area: Kentucky Phone number 270-869-6499. Zip code 42420 .
        His id is MR1234.
        Dr Vijay assissted him .
         John Smith drivers license is AC432223  Zip code: 10023
        My name is David .
        My  is ajaykhanna123ak@gmail.com.
        Name : Hendrickson, Ora, Record date: 2093-01-13, Age: 25, # 719435. Dr. John Green, ID: 1231511863, IP 203.120.223.13 
         He is a 60-year-old male was admitted to the Day Hospital for cystectomy on 01/13/93. Patient's VIN : 1HGBH41JXMN109286, SSN #333-44-6666,
         Driver's license no:A334455B. Phone (302) 786-5227, 0295 Keats Street, San Francisco, E-MAIL: smith@gmail.com"""
    

entities=[{'BeginOffset': 21,
'EndOffset': 33,
'Score': 0.999588668346405,
'Text': '212-555-5555',
'Type': 'OTHER'},
{'BeginOffset': 47,
'EndOffset': 51,
'Score': 0.9990673661231995,
'Text': 'Ajay',
'Type': 'PERSON'},
{'BeginOffset': 104,
'EndOffset': 129,
'Score': 0.9588755965232849,
'Text': '2425 Crosswind Drive City',
'Type': 'LOCATION'},
{'BeginOffset': 131,
'EndOffset': 140,
'Score': 0.7838751077651978,
'Text': 'Henderson',
'Type': 'LOCATION'},
{'BeginOffset': 163,
'EndOffset': 171,
'Score': 0.9967709183692932,
'Text': 'Kentucky',
'Type': 'LOCATION'},
{'BeginOffset': 185,
'EndOffset': 197,
'Score': 0.9996469020843506,
'Text': '270-869-6499',
'Type': 'OTHER'},
{'BeginOffset': 208,
'EndOffset': 213,
'Score': 0.994130551815033,
'Text': '42420',
'Type': 'OTHER'},
{'BeginOffset': 234,
'EndOffset': 240,
'Score': 0.9942786693572998,
'Text': 'MR1234',
'Type': 'OTHER'},
{'BeginOffset': 253,
'EndOffset': 258,
'Score': 0.998410701751709,
'Text': 'Vijay',
'Type': 'PERSON'},
{'BeginOffset': 284,
'EndOffset': 294,
'Score': 0.997890055179596,
'Text': 'John Smith',
'Type': 'PERSON'},
{'BeginOffset': 314,
'EndOffset': 322,
'Score': 0.9964033365249634,
'Text': 'AC432223',
'Type': 'OTHER'},
{'BeginOffset': 334,
'EndOffset': 339,
'Score': 0.9727945923805237,
'Text': '10023',
'Type': 'OTHER'},
{'BeginOffset': 359,
'EndOffset': 364,
'Score': 0.9950897693634033,
'Text': 'David',
'Type': 'PERSON'},
{'BeginOffset': 382,
'EndOffset': 407,
'Score': 0.9950774312019348,
'Text': 'ajaykhanna123ak@gmail.com',
'Type': 'OTHER'},
{'BeginOffset': 424,
'EndOffset': 436,
'Score': 0.9249659180641174,
'Text': 'Hendrickson,',
'Type': 'PERSON'},
{'BeginOffset': 437,
'EndOffset': 440,
'Score': 0.5278527736663818,
'Text': 'Ora',
'Type': 'PERSON'},
{'BeginOffset': 455,
'EndOffset': 465,
'Score': 0.6049607992172241,
'Text': '2093-01-13',
'Type': 'OTHER'},
{'BeginOffset': 472,
'EndOffset': 474,
'Score': 0.8899622559547424,
'Text': '25',
'Type': 'QUANTITY'},
{'BeginOffset': 476,
'EndOffset': 484,
'Score': 0.8343915343284607,
'Text': '# 719435',
'Type': 'OTHER'},
{'BeginOffset': 490,
'EndOffset': 500,
'Score': 0.9986414313316345,
'Text': 'John Green',
'Type': 'PERSON'},
{'BeginOffset': 506,
'EndOffset': 516,
'Score': 0.9987719655036926,
'Text': '1231511863',
'Type': 'OTHER'},
{'BeginOffset': 518,
'EndOffset': 535,
'Score': 0.5809402465820312,
'Text': 'IP 203.120.223.13',
'Type': 'OTHER'},
{'BeginOffset': 554,
'EndOffset': 565,
'Score': 0.9886900782585144,
'Text': '60-year-old',
'Type': 'QUANTITY'},
{'BeginOffset': 591,
'EndOffset': 603,
'Score': 0.838308572769165,
'Text': 'Day Hospital',
'Type': 'ORGANIZATION'},
{'BeginOffset': 622,
'EndOffset': 630,
'Score': 0.9920857548713684,
'Text': '01/13/93',
'Type': 'DATE'},
{'BeginOffset': 648,
'EndOffset': 665,
'Score': 0.9584269523620605,
'Text': '1HGBH41JXMN109286',
'Type': 'OTHER'},
{'BeginOffset': 672,
'EndOffset': 683,
'Score': 0.6988616585731506,
'Text': '333-44-6666',
'Type': 'OTHER'},
{'BeginOffset': 714,
'EndOffset': 722,
'Score': 0.998747706413269,
'Text': 'A334455B',
'Type': 'OTHER'},
{'BeginOffset': 730,
'EndOffset': 744,
'Score': 0.975226640701294,
'Text': '(302) 786-5227',
'Type': 'OTHER'},
{'BeginOffset': 746,
'EndOffset': 778,
'Score': 0.9376611113548279,
'Text': '0295 Keats Street, San Francisco',
'Type': 'LOCATION'},
{'BeginOffset': 788,
'EndOffset': 803,
'Score': 0.9962939620018005,
'Text': 'smith@gmail.com',
'Type': 'OTHER'}]

# %%
import re
data=text

for entity in entities:
    data=re.sub(entity['Text'],entity['Type'],data)

# %%
print(data)
# Out:
# 1.My phone number is OTHER.
#         Mr PERSON got fever and gave him paracetemol.
#         Street: LOCATION: LOCATION  State/province/area: LOCATION Phone number OTHER. Zip code OTHER .
#         His id is OTHER.
#         Dr PERSON assissted him .
#          PERSON drivers license is OTHER  Zip code: OTHER
#         My name is PERSON .
#         My  is OTHER.
#         Name : PERSON PERSON, Record date: OTHER, Age: QUANTITY, OTHER. Dr. PERSON, ID: OTHER, OTHER
#          He is a QUANTITY male was admitted to the ORGANIZATION for cystectomy on DATE. Patient's VIN : OTHER, SSN #OTHER,
#          Driver's license no:OTHER. Phone (302) 786-5227, LOCATION, E-MAIL: OTHER
