# %%
entities=[
    {
      "Id": 1,
      "BeginOffset": 21,
      "EndOffset": 33,
      "Score": 0.9998379945755005,
      "Text": "212-555-5555",
      "Category": "PROTECTED_HEALTH_INFORMATION",
      "Type": "PHONE_OR_FAX",
      "Traits": []
    },
    {
      "Id": 2,
      "BeginOffset": 47,
      "EndOffset": 51,
      "Score": 0.9793490171432495,
      "Text": "Ajay",
      "Category": "PROTECTED_HEALTH_INFORMATION",
      "Type": "NAME",
      "Traits": []
    },
    {
      "Id": 3,
      "BeginOffset": 104,
      "EndOffset": 129,
      "Score": 0.6000571846961975,
      "Text": "2425 Crosswind Drive City",
      "Category": "PROTECTED_HEALTH_INFORMATION",
      "Type": "ADDRESS",
      "Traits": []
    },
    {
      "Id": 4,
      "BeginOffset": 131,
      "EndOffset": 140,
      "Score": 0.9331986904144287,
      "Text": "Henderson",
      "Category": "PROTECTED_HEALTH_INFORMATION",
      "Type": "NAME",
      "Traits": []
    },
    {
      "Id": 5,
      "BeginOffset": 142,
      "EndOffset": 161,
      "Score": 0.4818730056285858,
      "Text": "State/province/area",
      "Category": "PROTECTED_HEALTH_INFORMATION",
      "Type": "ADDRESS",
      "Traits": []
    },
    {
      "Id": 6,
      "BeginOffset": 163,
      "EndOffset": 171,
      "Score": 0.6852316856384277,
      "Text": "Kentucky",
      "Category": "PROTECTED_HEALTH_INFORMATION",
      "Type": "ADDRESS",
      "Traits": []
    },
    {
      "Id": 7,
      "BeginOffset": 185,
      "EndOffset": 197,
      "Score": 0.9998372793197632,
      "Text": "270-869-6499",
      "Category": "PROTECTED_HEALTH_INFORMATION",
      "Type": "PHONE_OR_FAX",
      "Traits": []
    },
    {
      "Id": 8,
      "BeginOffset": 208,
      "EndOffset": 213,
      "Score": 0.22993962466716766,
      "Text": "42420",
      "Category": "PROTECTED_HEALTH_INFORMATION",
      "Type": "PHONE_OR_FAX",
      "Traits": []
    },
    {
      "Id": 9,
      "BeginOffset": 234,
      "EndOffset": 240,
      "Score": 0.29260551929473877,
      "Text": "MR1234",
      "Category": "PROTECTED_HEALTH_INFORMATION",
      "Type": "ID",
      "Traits": []
    },
    {
      "Id": 10,
      "BeginOffset": 253,
      "EndOffset": 258,
      "Score": 0.9726248383522034,
      "Text": "Vijay",
      "Category": "PROTECTED_HEALTH_INFORMATION",
      "Type": "NAME",
      "Traits": []
    },
    {
      "Id": 11,
      "BeginOffset": 284,
      "EndOffset": 294,
      "Score": 0.9963924288749695,
      "Text": "John Smith",
      "Category": "PROTECTED_HEALTH_INFORMATION",
      "Type": "NAME",
      "Traits": []
    },
    {
      "Id": 12,
      "BeginOffset": 314,
      "EndOffset": 322,
      "Score": 0.5120403170585632,
      "Text": "AC432223",
      "Category": "PROTECTED_HEALTH_INFORMATION",
      "Type": "PHONE_OR_FAX",
      "Traits": []
    },
    {
      "Id": 13,
      "BeginOffset": 334,
      "EndOffset": 339,
      "Score": 0.26176732778549194,
      "Text": "10023",
      "Category": "PROTECTED_HEALTH_INFORMATION",
      "Type": "PHONE_OR_FAX",
      "Traits": []
    },
    {
      "Id": 14,
      "BeginOffset": 359,
      "EndOffset": 364,
      "Score": 0.9984681010246277,
      "Text": "David",
      "Category": "PROTECTED_HEALTH_INFORMATION",
      "Type": "NAME",
      "Traits": []
    },
    {
      "Id": 15,
      "BeginOffset": 382,
      "EndOffset": 407,
      "Score": 0.9999884366989136,
      "Text": "ajaykhanna123ak@gmail.com",
      "Category": "PROTECTED_HEALTH_INFORMATION",
      "Type": "EMAIL",
      "Traits": []
    },
    {
      "Id": 16,
      "BeginOffset": 424,
      "EndOffset": 440,
      "Score": 0.5228571891784668,
      "Text": "Hendrickson, Ora",
      "Category": "PROTECTED_HEALTH_INFORMATION",
      "Type": "NAME",
      "Traits": []
    },
    {
      "Id": 17,
      "BeginOffset": 455,
      "EndOffset": 465,
      "Score": 0.9948179125785828,
      "Text": "2093-01-13",
      "Category": "PROTECTED_HEALTH_INFORMATION",
      "Type": "DATE",
      "Traits": []
    },
    {
      "Id": 18,
      "BeginOffset": 472,
      "EndOffset": 474,
      "Score": 0.5609111785888672,
      "Text": "25",
      "Category": "PROTECTED_HEALTH_INFORMATION",
      "Type": "AGE",
      "Traits": []
    },
    {
      "Id": 19,
      "BeginOffset": 478,
      "EndOffset": 484,
      "Score": 0.8244092464447021,
      "Text": "719435",
      "Category": "PROTECTED_HEALTH_INFORMATION",
      "Type": "ID",
      "Traits": []
    },
    {
      "Id": 20,
      "BeginOffset": 490,
      "EndOffset": 500,
      "Score": 0.999941349029541,
      "Text": "John Green",
      "Category": "PROTECTED_HEALTH_INFORMATION",
      "Type": "NAME",
      "Traits": []
    },
    {
      "Id": 21,
      "BeginOffset": 506,
      "EndOffset": 516,
      "Score": 0.9998911619186401,
      "Text": "1231511863",
      "Category": "PROTECTED_HEALTH_INFORMATION",
      "Type": "ID",
      "Traits": []
    },
    {
      "Id": 22,
      "BeginOffset": 521,
      "EndOffset": 535,
      "Score": 0.7798637747764587,
      "Text": "203.120.223.13",
      "Category": "PROTECTED_HEALTH_INFORMATION",
      "Type": "DATE",
      "Traits": []
    },
    {
      "Id": 23,
      "BeginOffset": 554,
      "EndOffset": 556,
      "Score": 0.9999315738677979,
      "Text": "60",
      "Category": "PROTECTED_HEALTH_INFORMATION",
      "Type": "AGE",
      "Traits": []
    },
    {
      "Id": 24,
      "BeginOffset": 591,
      "EndOffset": 603,
      "Score": 0.2988758385181427,
      "Text": "Day Hospital",
      "Category": "PROTECTED_HEALTH_INFORMATION",
      "Type": "ADDRESS",
      "Traits": []
    },
    {
      "Id": 25,
      "BeginOffset": 622,
      "EndOffset": 630,
      "Score": 0.9999707937240601,
      "Text": "01/13/93",
      "Category": "PROTECTED_HEALTH_INFORMATION",
      "Type": "DATE",
      "Traits": []
    },
    {
      "Id": 26,
      "BeginOffset": 648,
      "EndOffset": 665,
      "Score": 0.6508076786994934,
      "Text": "1HGBH41JXMN109286",
      "Category": "PROTECTED_HEALTH_INFORMATION",
      "Type": "ID",
      "Traits": []
    },
    {
      "Id": 27,
      "BeginOffset": 672,
      "EndOffset": 683,
      "Score": 0.9891409873962402,
      "Text": "333-44-6666",
      "Category": "PROTECTED_HEALTH_INFORMATION",
      "Type": "PHONE_OR_FAX",
      "Traits": []
    },
    {
      "Id": 28,
      "BeginOffset": 714,
      "EndOffset": 722,
      "Score": 0.8884153366088867,
      "Text": "A334455B",
      "Category": "PROTECTED_HEALTH_INFORMATION",
      "Type": "ID",
      "Traits": []
    },
    {
      "Id": 29,
      "BeginOffset": 730,
      "EndOffset": 744,
      "Score": 0.9389556050300598,
      "Text": "(302) 786-5227",
      "Category": "PROTECTED_HEALTH_INFORMATION",
      "Type": "PHONE_OR_FAX",
      "Traits": []
    },
    {
      "Id": 30,
      "BeginOffset": 746,
      "EndOffset": 778,
      "Score": 0.6770229339599609,
      "Text": "0295 Keats Street, San Francisco",
      "Category": "PROTECTED_HEALTH_INFORMATION",
      "Type": "ADDRESS",
      "Traits": []
    },
    {
      "Id": 31,
      "BeginOffset": 788,
      "EndOffset": 803,
      "Score": 0.9998321533203125,
      "Text": "smith@gmail.com",
      "Category": "PROTECTED_HEALTH_INFORMATION",
      "Type": "EMAIL",
      "Traits": []
    }
  ]

# %%
text="""1.My phone number is 212-555-5555. 
        Mr Ajay got fever and gave him paracetemol.
        Street: 2425 Crosswind Drive City: Henderson  State/province/area: Kentucky Phone number 270-869-6499. Zip code 42420 .
        His id is MR1234.
        Dr Vijay assissted him .
         John Smith drivers license is AC432223  Zip code: 10023
        My name is David .
        My  is ajaykhanna123ak@gmail.com.
        Name : Hendrickson, Ora, Record date: 2093-01-13, Age: 25, # 719435. Dr. John Green, ID: 1231511863, IP 203.120.223.13 
         He is a 60-year-old male was admitted to the Day Hospital for cystectomy on 01/13/93. Patient's VIN : 1HGBH41JXMN109286, SSN #333-44-6666,
         Driver's license no:A334455B. Phone (302) 786-5227, 0295 Keats Street, San Francisco, E-MAIL: smith@gmail.com"""

# %%
import re
data=text

for entity in entities:
#     print(entity['Text'],entity['Type'])
    data=re.sub(entity['Text'],entity['Type'],data)

# %%
print(data)
# Out:
# 1.My phone number is PHONE_OR_FAX.
#         Mr NAME got fever and gave him paracetemol.
#         Street: ADDRESS: NAME  ADDRESS: ADDRESS Phone number PHONE_OR_FAX. Zip code PHONE_OR_FAX .
#         His id is ID.
#         Dr NAME assissted him .
#          NAME drivers license is PHONE_OR_FAX  Zip code: PHONE_OR_FAX
#         My name is NAME .
#         My  is EMAIL.
#         Name : NAME, Record date: DATE, Age: AGE, # ID. Dr. NAME, ID: ID, IP DATE
#          He is a AGE-year-old male was admitted to the ADDRESS for cystectomy on DATE. Patient's VIN : ID, SSN #PHONE_OR_FAX,
#          Driver's license no:ID. Phone (302) 786-5227, ADDRESS, E-MAIL: EMAIL
